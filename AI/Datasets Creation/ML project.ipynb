# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Typical Datasets

# %%
# Importing blosum50 scoring matrix, adding column and row headers
df=pd.read_csv('TYP1.csv')
df.head(22)
# Out:
#     Happy_data_1  Happy_data_2  Happy_data_3  Happy_data_4  Happy_data_5  \
# 0      -6.356582     -6.945604     -7.374339     -8.022699     -9.317593
# 1      -4.183985     -3.306842     -3.210059     -4.214879     -6.341699
# 2     -10.746856    -10.491301    -10.944341    -12.047193    -13.596499
# 3      -6.267521     -5.355060     -5.595750     -7.136577     -9.721630
# 4      -3.797519     -4.204535     -5.207158     -6.670796     -8.280229
# 5      -2.302936     -2.451794     -2.915861     -3.609811     -4.351480
# 6      -1.252548     -1.078876     -1.167011     -1.532931     -2.061769
# 7      -7.746185     -6.614024     -5.487274     -5.089931     -6.095693
# 8       0.471738      0.476950     -1.091632     -3.724341     -6.715143
# 9      -6.161901     -6.373581     -7.736202    -10.143687    -13.108866
# 10     -2.690635     -2.535840     -3.083803     -4.454101     -6.488418
# 11     -3.920536     -4.069738     -4.601220     -5.468278     -6.451282
# ...

# %%
df.shape
# Out:
# (128, 99750)

# %%
wow = df.iloc[2,:]
# # # # # # # # ch2 = df.iloc[1,0:20000]
# # # # # # # #df.columns[20000]
print(wow)

# typ1ch = []

# for channel in range(0,128):
#     typ1ch.append(df.iloc[channel,:])
    
# #ch[127]
# print(typ1ch[0].shape)
# Out:
# Happy_data_1         -10.746856
# Happy_data_2         -10.491301
# Happy_data_3         -10.944341
# Happy_data_4         -12.047193
# Happy_data_5         -13.596499
# Happy_data_6         -15.138646
# Happy_data_7         -16.027704
# Happy_data_8         -15.635710
# Happy_data_9         -13.529844
# Happy_data_10         -9.538939
# Happy_data_11         -3.815619
# Happy_data_12          3.051153
# Happy_data_13          9.969863
# Happy_data_14         15.551407
# Happy_data_15         18.620399
# Happy_data_16         18.739086
# Happy_data_17         16.433205
# Happy_data_18         13.003575
# Happy_data_19         10.056000
# Happy_data_20          8.960295
# Happy_data_21         10.362699
# Happy_data_22         13.868129
# Happy_data_23         18.083146
# Happy_data_24         21.113246
# Happy_data_25         21.374722
# Happy_data_26         18.320816
# Happy_data_27         12.692351
# Happy_data_28          6.196187
# Happy_data_29          0.826463
# ...

# %%
df2=pd.read_csv('TYP2.csv')
print(df2.shape)
# Out:
# (128, 74750)

# %%
# ch1 = df2.iloc[0,0:14750]
# print(ch1)

typ2ch = []

for channel in range(0,128):
    typ2ch.append(df2.iloc[channel,:])
    
print(typ2ch[0].shape)
# Out:
# (74750,)

# %%
df3=pd.read_csv('TYP3.csv')
print(df3.shape)
# Out:
# (128, 99750)

# %%
# ch1 = df3.iloc[0,0:20001]
# print(ch1)

typ3ch = []

for channel in range(0,128):
    typ3ch.append(df3.iloc[channel,:])

# %%
df4=pd.read_csv('TYP4.csv')
print(df4.shape)
# Out:
# (128, 49750)

# %%
# ch1 = df4.iloc[0,0:10001]
# print(ch1)

typ4ch = []

for channel in range(0,128):
    typ4ch.append(df4.iloc[channel,:])

# %%
df5=pd.read_csv('TYP5.csv')
print(df5.shape)
# Out:
# (128, 99750)

# %%
# ch1 = df5.iloc[0,0:20001]
# print(ch1)

typ5ch = []

for channel in range(0,128):
    typ5ch.append(df5.iloc[channel,:])

# %%
df6=pd.read_csv('TYP6.csv')
print(df6.shape)
# Out:
# (128, 86750)

# %%
# ch1 = df6.iloc[0,0:17751]
# print(ch1)

typ6ch = []

for channel in range(0,128):
    typ6ch.append(df6.iloc[channel,:])

# %%
df7=pd.read_csv('TYP7.csv')
print(df7.shape)
# Out:
# (128, 24750)

# %%
# ch1 = df7.iloc[0,0:5001]
# print(ch1)

typ7ch = []

for channel in range(0,128):
    typ7ch.append(df7.iloc[channel,:])

# %%
df8=pd.read_csv('TYP8.csv')
print(df8.shape)
# Out:
# (128, 99750)

# %%
# ch1 = df8.iloc[0,0:20001]
# print(ch1)

typ8ch = []

for channel in range(0,128):
    typ8ch.append(df8.iloc[channel,:])

# %%
df9=pd.read_csv('TYP9.csv')
print(df9.shape)
# Out:
# (128, 74750)

# %%
# ch1 = df9.iloc[0,0:14751]
# print(ch1)

typ9ch = []

for channel in range(0,128):
    typ9ch.append(df9.iloc[channel,:])

# %%
df10=pd.read_csv('TYP10.csv')
print(df10.shape)
# Out:
# (128, 75500)

# %%
# ch1 = df10.iloc[0,0:15251]
# print(ch1)

typ10ch = []

for channel in range(0,128):
    typ10ch.append(df10.iloc[channel,:])

# %%
df11=pd.read_csv('TYP11.csv')
print(df11.shape)
# Out:
# (128, 74750)

# %%
# ch1 = df11.iloc[0,0:15001]
# print(ch1)

typ11ch = []

for channel in range(0,128):
    typ11ch.append(df11.iloc[channel,:])

# %%
df12=pd.read_csv('TYP12.csv')
print(df12.shape)
# Out:
# (128, 74750)

# %%
# ch1 = df12.iloc[0,0:15001]
# print(ch1)

typ12ch = []

for channel in range(0,128):
    typ12ch.append(df12.iloc[channel,:])

# %% [markdown]
# # Autism Datasets

# %%
# Importing blosum50 scoring matrix, adding column and row headers
df21=pd.read_csv('ASD1.csv')
# df21.head(22)

# %%
df21.shape
# Out:
# (128, 74500)

# %%
# t = df2.iloc[0,0:14750]
# ch2 = df.iloc[1,0:20000]
#df.columns[20000]
# print(t)

asd1ch = []

for channel in range(0,128):
    asd1ch.append(df21.iloc[channel,:])
    
# asd1ch[12]

# %%
df22=pd.read_csv('ASD2.csv')
print(df22.shape)
# Out:
# (128, 99750)

# %%
# ch1 = df22.iloc[0,0:20001]
# print(ch1)

asd2ch = []

for channel in range(0,128):
    asd2ch.append(df22.iloc[channel,:])

# %%
df23=pd.read_csv('ASD3.csv')
print(df23.shape)
# Out:
# (128, 99750)

# %%
# ch1 = df23.iloc[0,0:19751]
# print(ch1)

asd3ch = []

for channel in range(0,128):
    asd3ch.append(df23.iloc[channel,:])

# %%
df24=pd.read_csv('ASD4.csv')
print(df24.shape)
# Out:
# (128, 99750)

# %%
# ch1 = df24.iloc[0,0:19751]
# print(ch1)

asd4ch = []

for channel in range(0,128):
    asd4ch.append(df24.iloc[channel,:])

# %%
df25=pd.read_csv('ASD5.csv')
print(df25.shape)
# Out:
# (128, 49750)

# %%
# ch1 = df25.iloc[0,0:10001]
# print(ch1)

asd5ch = []

for channel in range(0,128):
    asd5ch.append(df25.iloc[channel,:])

# %%
df26=pd.read_csv('ASD6.csv')
print(df26.shape)
# Out:
# (128, 49750)

# %%
# ch1 = df26.iloc[0,0:10001]
# print(ch1)

asd6ch = []

for channel in range(0,128):
    asd6ch.append(df26.iloc[channel,:])

# %%
df27=pd.read_csv('ASD7.csv')
print(df27.shape)
# Out:
# (128, 99750)

# %%
# ch1 = df27.iloc[0,0:20001]
# print(ch1)

asd7ch = []

for channel in range(0,128):
    asd7ch.append(df27.iloc[channel,:])

# %%
df28=pd.read_csv('ASD8.csv')
print(df28.shape)
# Out:
# (128, 99750)

# %%
# ch1 = df28.iloc[0,0:20001]
# print(ch1)

asd8ch = []

for channel in range(0,128):
    asd8ch.append(df28.iloc[channel,:])

# %%
df29=pd.read_csv('ASD9.csv')
print(df29.shape)
# Out:
# (128, 99750)

# %%
# ch1 = df29.iloc[0,0:20001]
# print(ch1)

asd9ch = []

for channel in range(0,128):
    asd9ch.append(df29.iloc[channel,:])

# %%
df210=pd.read_csv('ASD10.csv')
print(df210.shape)
# Out:
# (128, 74750)

# %%
# ch1 = df210.iloc[0,0:15001]
# print(ch1)

asd10ch = []

for channel in range(0,128):
    asd10ch.append(df210.iloc[channel,:])

# %%
df211=pd.read_csv('ASD11.csv')
print(df211.shape)
# Out:
# (128, 24750)

# %%
# ch1 = df211.iloc[0,0:5001]
# print(ch1)

asd11ch = []

for channel in range(0,128):
    asd11ch.append(df211.iloc[channel,:])

# %%
df212=pd.read_csv('ASD12.csv')
print(df212.shape)
# Out:
# (128, 99750)

# %%
# wow = df212.iloc[1,19999]
# print(wow)

asd12ch = []

for channel in range(0,128):
    asd12ch.append(df212.iloc[channel,:])
    
# ch1 = np.array(asd12ch)
# print(ch1[0:20000])

# %% [markdown]
# # Concatenating channels from each dataset

# %%
chlist = []

for i in range(0,128):
    chlist.append([typ1ch[i], typ2ch[i],typ3ch[i],typ4ch[i],typ5ch[i],typ6ch[i],typ7ch[i],typ8ch[i],typ9ch[i],typ10ch[i],
                   typ11ch[i],
           typ12ch[i], asd1ch[i], asd2ch[i], asd3ch[i], asd4ch[i], asd5ch[i], asd6ch[i], asd7ch[i], asd8ch[i], asd9ch[i], 
           asd10ch[i],
          asd11ch[i],asd12ch[i]])
# ch1 = np.array(ch1)
# print(len(ch1))

reducedchlist = []

for j in range(0,128):
    flat_list = []
    for sublist in chlist[j]:
        for item in sublist:
            flat_list.append(item)
        
    reducedchlist.append(flat_list) 
    

# print(np.array(reducedchlist[0]))
# print(np.array(reducedchlist[1]))
# print(np.array(reducedchlist[2]))

channels = []

for z in range(0,128):
    channels.append(np.array(reducedchlist[z]))
    
print(channels[0])
print(channels[1])
print(channels[2])
# Out:
# [-6.35658215 -6.94560406 -7.37433917 ... -7.0794074  -5.68585089
#  -3.68634056]
# [-4.18398508 -3.30684154 -3.21005946 ...  2.64029992  3.33118258
#   3.15189952]
# [-10.74685562 -10.49130111 -10.9443409  ...   8.84139993  10.75483312
#   11.78927466]

# %%
# typlab = [0] * 187500
# # typ 187500 asd 194250 tot 381750
# asdlab = [1] * 194250
# typ neutral 187250 asd 194500
# typ fear 186500 asd 1945000
# typ tree 187250 asd 193750
# typ cartoon 186250 asd 194750
# typ final 934750 asd 971750

typlab = np.zeros(934750)
asdlab = np.ones(971750)

lab = np.append(typlab,asdlab)

# typlab = np.array(typlab)

print(lab)
print(lab.shape)
# Out:
# [0. 0. 0. ... 1. 1. 1.]
# (1906500,)

# %% [markdown]
# # Dataframe

# %%
# Preprocessing :
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from itertools import product
from sklearn.preprocessing import StandardScaler

# Classifiers
from sklearn.linear_model import LogisticRegression
#from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn import tree
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

# %%
d = {'CH1': channels[0], 'CH2': channels[1], 'CH3': channels[2], 'CH4': channels[3], 'CH5': channels[4],'CH6': channels[5],
     'CH7': channels[6],
     'CH8': channels[7],'CH9': channels[8],'CH10': channels[9],'CH11': channels[10],'CH12': channels[11],'CH13': channels[12],
     'CH14': channels[13],
  'CH15': channels[14],'CH16': channels[15],'CH17': channels[16],'CH18': channels[17],'CH19': channels[18],'CH20': channels[19],
     'CH21': channels[20],
  'CH22': channels[21],'CH23': channels[22],'CH24': channels[23],'CH25': channels[24],'CH26': channels[25],'CH27': channels[26],
     'CH28': channels[27],
  'CH29': channels[28],'CH30': channels[29],'CH31': channels[30],'CH32': channels[31],'CH33': channels[32],'CH34': channels[33],
     'CH35': channels[34],
  'CH36': channels[35],'CH37': channels[36],'CH38': channels[37],'CH39': channels[38],'CH40': channels[39],'CH41': channels[40],
     'CH42': channels[41],
  'CH43': channels[42],'CH44': channels[43],'CH45': channels[44],'CH46': channels[45],'CH47': channels[46],'CH48': channels[47],
     'CH49': channels[48],
     'CH50': channels[49],'CH51': channels[50],'CH52': channels[51], 'CH53': channels[52],'CH54': channels[53], 
     'CH55': channels[54],'CH56': channels[55],'CH57': channels[56],'CH58': channels[57], 'CH59': channels[58],
  'CH60': channels[59],'CH61': channels[60],'CH62': channels[61],'CH63': channels[62],'CH64': channels[63],'CH65': channels[64],
     'CH66': channels[65],
  'CH67': channels[66],'CH68': channels[67],'CH69': channels[68],'CH70': channels[69],'CH71': channels[70],'CH72': channels[71],
     'CH73': channels[72],
  'CH74': channels[73],'CH75': channels[74],'CH76': channels[75],'CH77': channels[76],'CH78': channels[77],'CH79': channels[78],
     'CH80': channels[79],
     'CH81': channels[80],'CH82': channels[81],'CH83': channels[82],'CH84': channels[83],'CH85': channels[84],
     'CH86': channels[85],
     'CH87': channels[86],'CH88': channels[87],'CH89': channels[88],'CH90': channels[89],
     'CH91': channels[90],'CH92': channels[91],'CH93': channels[92],'CH94': channels[93],
     'CH95': channels[94],'CH96': channels[95],'CH97': channels[96],'CH98': channels[97],
     'CH99': channels[98],'CH100': channels[99],'CH101': channels[100],'CH102': channels[101],
     'CH103': channels[102],'CH104': channels[103],'CH105': channels[104],'CH106': channels[105],
     'CH107': channels[106],'CH108': channels[107],'CH109': channels[108],'CH110': channels[109],
     'CH111': channels[110],'CH112': channels[111],'CH113': channels[112],'CH114': channels[113],'CH115': channels[114],
     'CH116': channels[115],'CH117': channels[116],'CH118': channels[117],'CH119': channels[118],
     'CH120': channels[119], 'CH121': channels[120],'CH122': channels[121],'CH123': channels[122],'CH124': channels[123],
     'CH125': channels[124],'CH126': channels[125],'CH127': channels[126],'CH128': channels[127],'Label': lab}
typasd = pd.DataFrame(data=d)

export_csv = typasd.to_csv (r'C:\Users\hp\Desktop\FinalData.csv', index = None, header=True)
# %store typasd

print(typasd.head())

print(typasd.shape)
X = typasd.drop(['Label'], axis = 1).values
Y = typasd['Label']

X = StandardScaler().fit_transform(X)

X_Train, X_Test, Y_Train, Y_Test = train_test_split(X, Y, test_size = 0.30, random_state = 101)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\hp\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2961, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-140-c0fa95c5c282>", line 37, in <module>
#     export_csv = typasd.to_csv (r'C:\Users\hp\Desktop\FinalData.csv', index = None, header=True)
#   File "C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\frame.py", line 1745, in to_csv
#     formatter.save()
#   File "C:\Users\hp\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py", line 171, in save
#     self._save()
#   File "C:\Users\hp\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py", line 286, in _save
#     self._save_chunk(start_i, end_i)
#   File "C:\Users\hp\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py", line 300, in _save_chunk
#     quoting=self.quoting)
# ...
